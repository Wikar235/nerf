# %% [markdown]
# # NERF MODEL

# %% [markdown]
# original paper - https://arxiv.org/pdf/2003.08934
#
# pytorch implemenatation with maths - https://papers-100-lines.medium.com/neural-radiance-fields-nerf-tutorial-in-100-lines-of-pytorch-code-365ef2a1013
#
# kaggle paper - https://www.kaggle.com/code/yousefalbasel/neural-radiance-fields-nerfs-with-pytorch-part-1

# %%
import matplotlib
